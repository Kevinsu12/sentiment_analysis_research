# %%
import pandas as pd
from openai import OpenAI
from dotenv import load_dotenv

# %%
PATH = 'data/earning_call_presentations/clean_tr_sp500_final_2015_2020.parquet'

# %%
df = pd.read_parquet(PATH)

# %%
load_dotenv()
client = OpenAI()

# %%
Prompt = (
    "Summarize its content clearly and objectively in 2–3 concise sentences. "
    "Only include factual information explicitly stated in the transcript, such as financial results, "
    "strategic initiatives, operational updates, or management guidance. "
    "Avoid any interpretation, sentiment, or forward-looking assumptions beyond the given text."
)

# %%
df = df.sort_values(by = ['transcriptid', 'componentorder'])

transcripts = df.groupby('transcriptid')['transcript_text'].agg(lambda segs: ' '.join(segs)).reset_index(name='full_transcript')

# %%
test = transcripts.iloc[:5]

# %%
summaries = []
for _, row in test.iterrows():
    transcript_id = row['transcriptid']
    text = row['full_transcript']
    
    messages = [
        {"role": "system",  "content": Prompt},
        {"role": "user",    "content": text}
    ]
    
    resp = client.chat.completions.create(
        model="gpt-4o",     
        messages=messages,
        max_tokens=500,     
        temperature=0.0
    )
    
    summary = resp.choices[0].message.content.strip()
    summaries.append({
        'transcriptid': transcript_id,
        'summary': summary
    })

# %%
summaries
# Out:
# [{'transcriptid': 743348.0,
#   'summary': 'Micron Technology reported a record quarterly revenue of $4.6 billion for the first quarter of 2015, with a GAAP net income of $1 billion and free cash flow of $923 million. The company anticipates continued favorable market conditions for 2015, driven by constrained DRAM supply and solid demand for both DRAM and NAND, with expected industry bit growth in the low to mid-20% range for DRAM and high-30% to mid-40% range for NAND. Micron is focusing on deploying advanced process technologies and expanding its 3D NAND production, with plans to add clean room space in Singapore and maintain a disciplined approach to market supply.'},
#  {'transcriptid': 743536.0,
#   'summary': 'During the First Quarter Fiscal Year 2015 earnings call, Monsanto reported an ongoing EPS of $0.47, surpassing expectations, and a free cash flow of $969 million. The company highlighted its strategic focus on innovation and growth, particularly in its R&D pipeline, which includes advancements in breeding, biotechnology, and new platforms like microbial seed treatments and digital agriculture. Monsanto confirmed its full-year EPS guidance of $5.75 to $6 per share, despite facing challenges such as currency headwinds and shifts in agricultural acreage.'},
#  {'transcriptid': 743948.0,
#   'summary': "Constellation Brands reported strong third-quarter fiscal 2015 results, driven by significant growth in its beer segment, which saw depletion growth of 8% and contributed to an upward revision of the company's overall EPS guidance for the fiscal year. The company is investing in brewery expansion in Nava, Mexico, and implementing a glass-sourcing strategy to support future growth. The wine and spirits segment experienced EBIT growth, with spirits sales up over 25%, although U.S. wine results did not meet growth expectations due to market conditions and competitive pressures."},
#  {'transcriptid': 743950.0,
#   'summary': 'Family Dollar reported its first quarter fiscal 2015 earnings, with earnings per diluted share at $0.36 on a GAAP basis and $0.44 excluding merger-related fees, compared to $0.68 in the previous year. The company faced challenges with gross margin pressure due to investments in everyday low pricing (EDLP) and a shift towards lower-margin consumable categories, although there was sales growth in food, tobacco, and seasonal areas. The company is focused on improving execution, increasing profitability, and stabilizing key categories, while also managing costs and reducing store manager turnover.'},
#  {'transcriptid': 744008.0,
#   'summary': 'Bed Bath & Beyond reported third-quarter fiscal 2014 net earnings per diluted share of $1.23, including $0.04 from nonrecurring items, with net sales of $2.9 billion, a 2.7% increase from the previous year, and a comparable sales increase of 1.7%. The company continues to model fourth-quarter net earnings per diluted share between $1.78 and $1.83, and full-year net earnings per diluted share between $5.05 and $5.09. The company is investing in technology and omnichannel capabilities, with plans to open approximately 30 new stores across all concepts in fiscal 2015.'}]
